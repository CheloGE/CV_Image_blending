% %% [markdown]
% # Poisson image editing - Mixing gradients
% Author: Marcelo R. Garcia E.
%
%  <img src="Instructions.png" alt="Flowers in Chania">

% %% [markdown]
% ## Visualization
%
% Lets first visualize all resources we have to start this project

% %%
[target,map1]=imread('target_2.jpg');
[source,map2]=imread('source_2.jpg');
[mask,map3]=imread('mask_2.bmp');
subplot(1,3,1), imshow(source,map2)
title('Source')
subplot(1,3,2), imshow(target,map1)
title('target')
subplot(1,3,3), imshow(mask,map3)
title('mask')

% %% [markdown]
% ### All logic is developed in the `PoissonMixingGradients.m` function file.
%
% To check all logic please open the file outside this jupyter notebook. If you only want to run it simply run the below cell:

% %%
Image_blended = PoissonMixingGradients;

% %%
# show output from the function
imshow(Image_blended)
